# %%
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
import pandas as pd

max_results_per_city = 10

city_set = ['New+York','Chicago','San+Francisco', 'Austin', 'Seattle', 'Los+Angeles']
columns = ["city","job_title", "company_name", "location"]
sample_df = pd.DataFrame(columns = columns)

# %%
sample_df
# Out:
# Empty DataFrame
# Columns: [city, job_title, company_name, location]
# Index: []

# %%
#scraping code:
for city in city_set:
    
    for start in range(0, max_results_per_city, 10):
        
        page = requests.get('http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=' + str(city) + '&start=' + str(start))
        time.sleep(1)  #ensuring at least 1 second between page grabs
        
        soup = BeautifulSoup(page.text, "lxml", from_encoding="utf-8")
        
        for div in soup.find_all(name="div", attrs={"class":"row"}): 
            #specifying row num for index of job posting in dataframe
            num = (len(sample_df) + 1) 
            
            #creating an empty list to hold the data for each posting
            job_post = [] 
            
            #append city name
            job_post.append(city) 
            
            #grabbing job title
            for a in div.find_all(name="a", attrs={"data-tn-element":"jobTitle"}):
                job_post.append(a["title"]) 
                
            #grabbing company name
            company = div.find_all(name="span", attrs={"class":"company"}) 
            if len(company) > 0: 
                for b in company:
                    job_post.append(b.text.strip()) 
            else: 
                sec_try = div.find_all(name="span", attrs={"class":"result-link-source"})
                for span in sec_try:
                    job_post.append(span.text)
                    
            #grabbing location name
            c = div.findAll('span', attrs={'class': 'location'}) 
            for span in c: 
                job_post.append(span.text) 

            #appending list of job post info to dataframe at index num
        
            sample_df.loc[num] = job_post

#saving sample_df as a local csv file — define your own local path to save contents 
sample_df.to_csv("job_listings.csv", encoding='utf-8')
# Out:
# C:\Users\PankajR\anaconda3\lib\site-packages\bs4\__init__.py:203: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")

# %%
sample_df
# Out:
#         city                                          job_title  \
# 1   New+York                                     Data Scientist
# 2   New+York                                     Data Scientist
# 3   New+York                                     Data Scientist
# 4   New+York                                     Data Scientist
# 5   New+York         Research Scientist-Center for Data Science
# 6   New+York                              Junior Data Scientist
# 7   New+York            People Data Scientist, People Analytics
# 8   New+York                           Data Scientist, Podcasts
# 9   New+York                            Research Data Scientist
# 10  New+York                              Senior Data Scientist
# 11  New+York                          Data Scientist, Messaging
# 12  New+York                Data Scientist, Spotify for Artists
# 13  New+York                                 Jr. Data Scientist
# 14  New+York                                     Data Scientist
# 15  New+York                                     Data Scientist
# 16   Chicago                                     Data Scientist
# 17   Chicago                                     Data Scientist
# 18   Chicago                                     Data Scientist
# 19   Chicago                                     Data Scientist
# 20   Chicago                          Venmo Risk Data Scientist
# 21   Chicago                  Data Scientist / Analyst (Remote)
# 22   Chicago                                     Data Scientist
# 23   Chicago      Associate Data Scientist - Provider & Network
# 24   Chicago                            Data Scientist - Remote
# 25   Chicago                                     Data Scientist
# 26   Chicago                                     Data Scientist
# 27   Chicago                                     Data Scientist
# 28   Chicago                   Data Scientist (Experimentation)
# 29   Chicago                            Data Science Consultant
# 30   Chicago                              Senior Data Scientist
# 31    Austin                                     Data Scientist
# 32    Austin                                     Data Scientist
# 33    Austin                                     Data Scientist
# 34    Austin                              Senior Data Scientist
# 35    Austin                                     Data Scientist
# 36    Austin                              Senior Data Scientist
# 37    Austin                          Data Scientist, Analytics
# 38    Austin                     Data Scientist, Auction Expert
# 39    Austin                                   Data Scientist 2
# 40    Austin                               Process Data Analyst
# 41    Austin                              Data Science Resident
# 42    Austin                              Senior Data Scientist
# 43    Austin            Senior Product Data Scientist, Cash App
# 44    Austin                              Senior Data Scientist
# 45    Austin                  Data Scientist, Product Analytics
# 46   Seattle                                     Data Scientist
# 47   Seattle                             Data Scientist, Junior
# 48   Seattle                                    Data Scientists
# 49   Seattle                           Data & Applied Scientist
# 50   Seattle                          Data Scientist, Analytics
# 51   Seattle                                     Data Scientist
# 52   Seattle                                     Data Scientist
# 53   Seattle                               Staff Data Scientist
# 54   Seattle                            Security Data Scientist
# 55   Seattle  Data Scientist – Societal Resilience – Microso...
# 56   Seattle                                     Data Analyst 2
# 57   Seattle                                   Data Scientist 1
# 58   Seattle                              Senior Data Scientist
# 59   Seattle                              Data Science Resident
# 60   Seattle                                     Data Scientist
#
#                                      company_name  \
# 1             Albert Einstein College of Medicine
# 2                              Source Enterprises
# 3                                  Risk Solutions
# 4                                           Caden
# 5                             New York University
# 6                                        Decode_M
# 7                                            Uber
# 8                                         Spotify
# 9                                        Barclays
# 10                                        Corning
# 11                                        Spotify
# 12                                        Spotify
# 13                                        Kubient
# 14                                        Reonomy
# 15                                           DMGT
# 16                                    GAINSystems
# 17                                        Waystar
# 18                      The University of Chicago
# 19                            Enova International
# 20                                         PayPal
# 21                                          Avant
# 22                                          Eleks
# 23  Blue Cross Blue Shield of IL, MT, NM, OK & TX
# 24                                            FNA
# 25                                Rewards Network
# 26                                Walker & Dunlop
# 27                                       WiTronix
# 28                         Grubhub Holdings, Inc.
# 29                                      Accenture
# 30                      The University of Chicago
# 31                                   YETI Coolers
# 32                                     CDK Global
# 33                                            IBM
# 34                                         Bumble
# 35                                       ANALYTOS
# 36                                         Splunk
# 37                                       Facebook
# 38                                       Facebook
# 39                                         PayPal
# 40                                         dentsu
# 41                                 Galvanize Inc.
# 42                                       One Drop
# 43                                       Cash App
# 44                                      eBay Inc.
# 45                                       Facebook
# 46                                      Microsoft
# 47                            Booz Allen Hamilton
# 48                                     Ars Quanta
# 49                                      Microsoft
# 50                                       Facebook
# 51                                Electronic Arts
# 52                                         Criteo
# 53            The Walt Disney Company (Corporate)
# 54                                      Microsoft
# 55                                      Microsoft
# 56                                      Nordstrom
# 57                                      eBay Inc.
# 58                                      Microsoft
# 59                                 Galvanize Inc.
# 60                           Harman International
#
#                                      location
# 1          Bronx, NY 10461 (Parkchester area)
# 2           New York, NY 10036 (Midtown area)
# 3           New York, NY 10169 (Midtown area)
# 4           New York, NY 10013 (Tribeca area)
# 5                                New York, NY
# 6                                New York, NY
# 7                                New York, NY
# 8                                New York, NY
# 9           New York, NY 10020 (Midtown area)
# 10                          Corning, NY 14831
# 11                               New York, NY
# 12                               New York, NY
# 13                               New York, NY
# 14       New York, NY 10017 (Turtle Bay area)
# 15                               New York, NY
# 16       Chicago, IL 60622 (Wicker Park area)
# 17                                Chicago, IL
# 18                                Chicago, IL
# 19                                Chicago, IL
# 20              Chicago, IL 60654 (Loop area)
# 21                                Chicago, IL
# 22                                Chicago, IL
# 23                                Chicago, IL
# 24                                Chicago, IL
# 25    Chicago, IL 60606 (West Loop Gate area)
# 26          Chicago, IL 60606 (The Loop area)
# 27                      Bolingbrook, IL 60440
# 28          Chicago, IL 60602 (The Loop area)
# 29                                Chicago, IL
# 30          Chicago, IL 60637 (Woodlawn area)
# 31                                 Austin, TX
# 32                           Austin, TX 78730
# 33         Austin, TX 73301 (St Edwards area)
# 34                                 Austin, TX
# 35                                 Austin, TX
# 36         Austin, TX 73301 (St Edwards area)
# 37                                 Austin, TX
# 38                                 Austin, TX
# 39                           Austin, TX 78729
# 40           Austin, TX 78701 (Downtown area)
# 41           Austin, TX 78701 (Downtown area)
# 42                                 Austin, TX
# 43                                 Austin, TX
# 44                                 Austin, TX
# 45                                 Austin, TX
# 46          Redmond, WA 98052 (Overlake area)
# 47    Seattle, WA 98101 (Denny Triangle area)
# 48                                Seattle, WA
# 49                               Bellevue, WA
# 50  Seattle, WA 98109 (South Lake Union area)
# 51                                Seattle, WA
# 52          Seattle, WA 98109 (Westlake area)
# 53                                Seattle, WA
# 54          Redmond, WA 98052 (Overlake area)
# 55          Redmond, WA 98052 (Overlake area)
# 56                                Seattle, WA
# 57               Bellevue, WA (Downtown area)
# 58          Redmond, WA 98052 (Overlake area)
# 59                          Seattle, WA 98104
# 60                                Redmond, WA
